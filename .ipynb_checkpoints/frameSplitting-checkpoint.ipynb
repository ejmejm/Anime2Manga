# %%
import cv2
import matplotlib.pyplot as plt
from copy import deepcopy

# %matplotlib inline

# %%
frame_path = 'data/frames/'

# %%
vidcap = cv2.VideoCapture('data/anime/bnha23.mp4')
frame_skip = 2

success = True

frames = []

count = 0
while success and count <= 2000:
    if count % 50 == 0:
        success, image = vidcap.read()
        frames.append(image)
        cv2.imwrite(frame_path + 'frame' + str(count//frame_skip) + '.jpg', image)
    else:
        vidcap.grab()
    if count % 1000 == 0:
        print('Read frame #', count, ':', success)
    count += 1
# Out:
# Read frame # 0 : True
# Read frame # 1000 : True
# Read frame # 2000 : True
# Read frame # 3000 : True
# Read frame # 4000 : True
# Read frame # 5000 : True
# Read frame # 6000 : True
# Read frame # 7000 : True
# Read frame # 8000 : True
# Read frame # 9000 : True
# Read frame # 10000 : True

# %%
plt.imshow(frames[0])

# %%
def imgToOutline(img, threshold=6, invert=False):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.GaussianBlur(img, (3, 3), 0)
    img = cv2.Laplacian(img, cv2.CV_64F)
    
    if invert:
        main = 0
        back = 255
    else:
        main = 255
        back = 0
        
    
    for i in range(len(img)):
        for j in range(len(img[i])):
            if abs(img[i, j]) >= threshold:
                img[i, j] = main
            else:
                img[i, j] = back

    return img

# %%
gray = cv2.cvtColor(frames[0], cv2.COLOR_BGR2GRAY)
fig = plt.figure()
plt.imshow(gray, cmap='gray')
img = cv2.GaussianBlur(gray, (3, 3), 0)
fig = plt.figure()
plt.imshow(img, cmap='gray')
laplacian = cv2.Laplacian(img, cv2.CV_64F)
fig = plt.figure()
plt.imshow(laplacian, cmap='gray')

outline = deepcopy(laplacian)

threshold = 6
for i in range(len(outline)):
    for j in range(len(outline[i])):
        if abs(outline[i, j]) >= threshold:
            outline[i, j] = 0
        else:
            outline[i, j] = 255

fig = plt.figure()
plt.imshow(outline, cmap='gray')

# %%
cv2.imwrite('test.jpg', outline)
# Out:
# True
